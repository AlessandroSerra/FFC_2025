# %%
from scipy.constants import electron_volt, atomic_mass

# %%
electron_volt   # 1 eV
# Out:
# 1.602176634e-19

# %%
atomic_mass     # kg
# Out:
# 1.66053906892e-27

# %%
A = 1e-10   # m

# %%
fs = 1e-15  # s

# %%
# partiamo da energia in eV
# 1 eV = 1.602176634e-19 J = 1.602176634e-19 kg * m^2 / s^2
# 1 kg = 1/uma

# %%
eV_to_AMU_A2_fs2 = electron_volt / atomic_mass * (1e10)**2 / (1e15)**2
eV_to_AMU_A2_fs2
# Out:
# 0.009648533202185007
